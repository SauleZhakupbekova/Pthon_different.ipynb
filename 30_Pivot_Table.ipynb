# %% [markdown]
# ## Импортируем данные

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../archive/student-mat.csv')

# %%
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
data.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %% [markdown]
# #### Соберем данные для анализа Dalc и Walc

# %%
data_for_bar = data[['age', 'Dalc', 'Walc']]

# %%
data_for_bar.head()
# Out:
#    age  Dalc  Walc
# 0   18     1     1
# 1   17     1     1
# 2   15     2     3
# 3   15     1     1
# 4   16     1     2

# %%
plt.bar(x=data_for_bar.age, height=data_for_bar.Dalc)
# Out:
# <BarContainer object of 395 artists>

# %%
plt.bar(x=data_for_bar.age, height=data_for_bar.Walc)
# Out:
# <BarContainer object of 395 artists>

# %%
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
data_pivot = data.pivot_table(index=['school', 'sex', 'age'], 
                              values=['Dalc', 'Walc', 'health'], 
                              aggfunc=['mean', 'count'])

# %%
data_pivot
# Out:
#                     mean                     count
#                     Dalc      Walc    health  Dalc Walc health
# school sex age
# GP     F   15   1.315789  1.842105  3.500000    38   38     38
#            16   1.240741  2.037037  3.462963    54   54     54
#            17   1.260000  2.140000  3.400000    50   50     50
#            18   1.137931  1.620690  3.172414    29   29     29
#            19   1.333333  2.000000  3.166667    12   12     12
#        M   15   1.386364  1.954545  3.659091    44   44     44
#            16   1.640000  2.540000  3.960000    50   50     50
#            17   1.944444  3.277778  3.972222    36   36     36
#            18   1.750000  3.071429  3.535714    28   28     28
#            19   1.166667  1.333333  3.500000     6    6      6
#            20   1.000000  1.000000  5.000000     1    1      1
#            22   5.000000  5.000000  1.000000     1    1      1
# MS     F   17   1.125000  2.000000  2.500000     8    8      8
# ...

# %%
data_pivot.query('sex == "F" and age < 18')
# Out:
#                     mean                     count
#                     Dalc      Walc    health  Dalc Walc health
# school sex age
# GP     F   15   1.315789  1.842105  3.500000    38   38     38
#            16   1.240741  2.037037  3.462963    54   54     54
#            17   1.260000  2.140000  3.400000    50   50     50
# MS     F   17   1.125000  2.000000  2.500000     8    8      8

# %%
data.pivot_table(index=['school'], 
                              values=['Dalc', 'Walc', 'health'], 
                              aggfunc=['mean', 'count'])
# Out:
#             mean                     count
#             Dalc      Walc    health  Dalc Walc health
# school
# GP      1.444126  2.260745  3.575931   349  349    349
# MS      1.760870  2.521739  3.391304    46   46     46

# %%
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
data['student_id'] = data.index + 1000

# %%
data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   freetime goout  Dalc  Walc  health absences  G1  G2  G3 student_id
# 0        3     4     1     1       3        6   5   6   6       1000
# 1        3     3     1     1       3        4   5   5   6       1001
# 2        3     2     2     3       3       10   7   8  10       1002
# 3        2     2     1     1       5        2  15  14  15       1003
# 4        3     2     1     2       5        4   6  10  10       1004
#
# [5 rows x 34 columns]

# %%
data.query('Dalc == 5')
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 1029     GP   M   16       U     GT3       T     4     4   teacher   teacher
# 1061     GP   F   16       U     GT3       T     1     1  services  services
# 1066     GP   M   15       U     GT3       A     4     4     other  services
# 1100     GP   M   16       U     GT3       T     4     4  services  services
# 1223     GP   M   18       U     GT3       T     2     2     other     other
# 1236     GP   M   17       U     LE3       T     2     2     other     other
# 1247     GP   M   22       U     GT3       T     3     1  services  services
# 1327     GP   M   17       R     GT3       T     2     2  services     other
# 1349     MS   M   18       R     GT3       T     3     2     other     other
#
#       ... freetime goout  Dalc  Walc  health absences  G1  G2  G3 student_id
# 1029  ...        4     5     5     5       5       16  10  12  11       1029
# ...

# %% [markdown]
# ### Чаще всего пьют ...
# ### Реже всего пьют ...
