# %%
import pandas as pd

# %%
data = pd.read_csv('winequality-red.csv')#kaggle site with datasets https://www.kaggle.com/

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
data[data['quality']>7]['quality']
# Out:
# 267     8
# 278     8
# 390     8
# 440     8
# 455     8
# 481     8
# 495     8
# 498     8
# 588     8
# 828     8
# 1061    8
# 1090    8
# 1120    8
# 1202    8
# 1269    8
# 1403    8
# 1449    8
# 1549    8
# Name: quality, dtype: int64

# %%
data[data['quality'].isna()] #gives results of lost data (NA)
# Out:
# Empty DataFrame
# Columns: [fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality]
# Index: []

# %%
df =pd.DataFrame ([[1,2,3], [4,5], [6,7,8], [9]], columns=['a','b','c'])

# %%
df
# Out:
#    a    b    c
# 0  1  2.0  3.0
# 1  4  5.0  NaN
# 2  6  7.0  8.0
# 3  9  NaN  NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       4 non-null      int64
#  1   b       3 non-null      float64
#  2   c       2 non-null      float64
# dtypes: float64(2), int64(1)
# memory usage: 224.0 bytes

# %%
df[df.a.isna()]
# Out:
# Empty DataFrame
# Columns: [a, b, c]
# Index: []

# %%
df[df.b.isna()]
# Out:
#    a   b   c
# 3  9 NaN NaN

# %%
df[df.c.isna()]
# Out:
#    a    b   c
# 1  4  5.0 NaN
# 3  9  NaN NaN

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
data['quality'].describe()
# Out:
# count    1599.000000
# mean        5.636023
# std         0.807569
# min         3.000000
# 25%         5.000000
# 50%         6.000000
# 75%         6.000000
# max         8.000000
# Name: quality, dtype: float64

# %%
data.corr() #correlation
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
df = pd.DataFrame([[5,1,20], [8,1,25], [15,2,50], [100,3,230], 
                   [20,2,56], [30,2,80], [670,3,1000]])

# %%
df
# Out:
#      0  1     2
# 0    5  1    20
# 1    8  1    25
# 2   15  2    50
# 3  100  3   230
# 4   20  2    56
# 5   30  2    80
# 6  670  3  1000

# %%
df.corr()
# Out:
#           0         1         2
# 0  1.000000  0.632783  0.997645
# 1  0.632783  1.000000  0.679184
# 2  0.997645  0.679184  1.000000

# %%
import random as rd

# %%
df2 = pd.DataFrame({'a':[rd.randint(1, 100000) for i in range(10)],
                    'b':[rd.randint(100, 200) for i in range(10)]})

# %%
df2
# Out:
#        a    b
# 0  51910  152
# 1  27659  116
# 2  82548  187
# 3  64479  182
# 4  68839  130
# 5  16943  161
# 6  82745  149
# 7  92349  191
# 8  19156  137
# 9  75083  191

# %%
df2.corr()
# Out:
#           a         b
# a  1.000000  0.271955
# b  0.271955  1.000000

# %%
df2 = pd.DataFrame({'a':[rd.randint(1, 100000) for i in range(10)],
                    'b':[1 for i in range(9)]+[2]})

# %%
df2
# Out:
#        a  b
# 0  35744  1
# 1  11262  1
# 2  13531  1
# 3   3344  1
# 4  71916  1
# 5  41041  1
# 6  64795  1
# 7  56279  1
# 8   4681  1
# 9   8184  2

# %%
df2.corr()
# Out:
#           a         b
# a  1.000000 -0.305216
# b -0.305216  1.000000

# %%
a = 10
res = []
for i in range (a):
    vr = []
    vr.append(a-i)
    vr.append(i)
    res.append(vr)
df3 = pd.DataFrame(res, columns = ['a', 'b'])

# %%
df3
# Out:
#     a  b
# 0  10  0
# 1   9  1
# 2   8  2
# 3   7  3
# 4   6  4
# 5   5  5
# 6   4  6
# 7   3  7
# 8   2  8
# 9   1  9

# %%
df3.corr()
# Out:
#      a    b
# a  1.0 -1.0
# b -1.0  1.0

# %%
data.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
input_data = data[['volatile acidity', 'citric acid', 'alcohol']]

# %%
input_data
# Out:
#       volatile acidity  citric acid  alcohol
# 0                0.700         0.00      9.4
# 1                0.880         0.00      9.8
# 2                0.760         0.04      9.8
# 3                0.280         0.56      9.8
# 4                0.700         0.00      9.4
# ...                ...          ...      ...
# 1594             0.600         0.08     10.5
# 1595             0.550         0.10     11.2
# 1596             0.510         0.13     11.0
# 1597             0.645         0.12     10.2
# 1598             0.310         0.47     11.0
#
# [1599 rows x 3 columns]

# %%
output_data = data['quality']

# %%
output_data
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %%
import seaborn as sb #charts and heatmap

# %%
sb.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %%
from sklearn import linear_model as lm #line regression model

# %%
data[['density', 'fixed acidity']].plot()
# Out:
# <AxesSubplot:>

# %%
data[['citric acid', 'fixed acidity']].plot()
# Out:
# <AxesSubplot:>

# %%
x = [i for i in range(1,20)]
y = [i * (1 + rd.randint(0,1)) for i in x]
sb.scatterplot(x=x, y=y)
# Out:
# <AxesSubplot:>

# %%
reg = lm.LinearRegression()

# %%
reg.fit(input_data, output_data)
# Out:
# LinearRegression()

# %%
input_data.loc[267]
# Out:
# volatile acidity     0.35
# citric acid          0.46
# alcohol             12.80
# Name: 267, dtype: float64

# %%
output_data[output_data == 8]
# Out:
# 267     8
# 278     8
# 390     8
# 440     8
# 455     8
# 481     8
# 495     8
# 498     8
# 588     8
# 828     8
# 1061    8
# 1090    8
# 1120    8
# 1202    8
# 1269    8
# 1403    8
# 1449    8
# 1549    8
# Name: quality, dtype: int64

# %%
reg.predict(pd.DataFrame([[0.35, 0.46, 12.8]]))
# Out:
# array([6.63361971])

# %%
# result - it is not linear regression
